# %% [markdown]
# # Binary Classification on Tabular Data - Predicting Heart Disease

# %% [markdown]
# ## Introduction
#
# This colab shows how to set up and train a Neural Network model for *binary classification*, when the dataset is *tabular* (rather than unstructured data like images or text) and has a mix of numeric and categorical features. Since tabular datasets are often made available in CSV files, the colab demonstrates the full CSV-to-trained-model workflow.
#
#
#
#
# ### The dataset
#
# The dataset ([more background on the data](https://archive.ics.uci.edu/ml/datasets/heart+Disease)) has information on 303 patients, one in each row. Each column (i.e., feature) contains information on a particular attribute of the patient. The column named "Target" indicates if the patient has been diagnosed with heart disease or not and is the label (i.e., the dependent variable) that we want to predict using the other columns.
#
# Feature description (copied from [here](https://keras.io/examples/structured_data/structured_data_classification_from_scratch/)):
#
# Column| Description| Feature Type
# ------------|--------------------|----------------------
# Age | Age in years | Numerical
# Sex | (1 = male; 0 = female) | Categorical
# CP | Chest pain type (0, 1, 2, 3, 4) | Categorical
# Trestbpd | Resting blood pressure (in mm Hg on admission) | Numerical
# Chol | Serum cholesterol in mg/dl | Numerical
# FBS | fasting blood sugar in 120 mg/dl (1 = true; 0 = false) | Categorical
# RestECG | Resting electrocardiogram results (0, 1, 2) | Categorical
# Thalach | Maximum heart rate achieved | Numerical
# Exang | Exercise induced angina (1 = yes; 0 = no) | Categorical
# Oldpeak | ST depression induced by exercise relative to rest | Numerical
# Slope | Slope of the peak exercise ST segment | Numerical
# CA | Number of major vessels (0-3) colored by fluoroscopy | Both numerical & categorical
# Thal | 3 = normal; 6 = fixed defect; 7 = reversible defect | Categorical
# Target | Diagnosis of heart disease (1 = true; 0 = false) | Target

# %% [markdown]
# ## Technical preliminaries
#
# Throughout the course, we will load the following packages as the first step.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# When we train Deep Learning models, randomness enters the process in a few different places.
# *   Starting values for the weights (the optimizer will try to improve these weights)
# *   The order in which we process the minibatches when we do SGD
# *   When we split the data into Train, Validation, Test etc
# *   Dropout (if we use regularization)
#
# We next set the seed for the different random number generators so that the
# results will be the same every time the notebook is run. 🤞

# %%
keras.utils.set_random_seed(42)

# %% [markdown]
# ## Read in the data
#
# Conveniently, the dataset in CSV form has been made available online (by [Francois Chollet](https://twitter.com/fchollet)) and we can load it into a Pandas dataframe with the very useful `pd.read_csv` command.

# %%
df = pd.read_csv("http://storage.googleapis.com/download.tensorflow.org/data/heart.csv")

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# The dataset has 303 rows and 14 columns (13 independent variables + 1 dependent variable):

# %% [markdown]
# Let's take a look at the first few rows:

# %%
df.head(15)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   1       145   233    1        2      150      0      2.3
# 1    67    1   4       160   286    0        2      108      1      1.5
# 2    67    1   4       120   229    0        2      129      1      2.6
# 3    37    1   3       130   250    0        0      187      0      3.5
# 4    41    0   2       130   204    0        2      172      0      1.4
# 5    56    1   2       120   236    0        0      178      0      0.8
# 6    62    0   4       140   268    0        2      160      0      3.6
# 7    57    0   4       120   354    0        0      163      1      0.6
# 8    63    1   4       130   254    0        2      147      0      1.4
# 9    53    1   4       140   203    1        2      155      1      3.1
# 10   57    1   4       140   192    0        0      148      0      0.4
# 11   56    0   2       140   294    0        2      153      0      1.3
# 12   56    1   3       130   256    1        2      142      1      0.6
# 13   44    1   2       120   263    0        0      173      0      0.0
# 14   52    1   3       172   199    1        0      162      0      0.5
#
#     slope  ca        thal  target
# 0       3   0       fixed       0
# 1       2   3      normal       1
# 2       2   2  reversible       0
# 3       3   0      normal       0
# 4       1   0      normal       0
# 5       1   0      normal       0
# 6       3   2      normal       1
# 7       1   0      normal       0
# 8       2   1  reversible       1
# 9       3   0  reversible       0
# 10      2   0       fixed       0
# 11      2   0      normal       0
# 12      2   1       fixed       1
# 13      1   0  reversible       0
# 14      1   0  reversible       0

# %% [markdown]
# Let's take a quick look to see if the 1s and 0s are balanced.

# %%
df.target.value_counts(normalize=True, dropna=False)
# Out:
# target
# 0    0.726073
# 1    0.273927
# Name: proportion, dtype: float64

# %% [markdown]
# It is a bit imbalanced.
#
# What's a 'naive' **baseline model** for this problem?
#
# <br> <br> <br> <br>

# %% [markdown]
# A baseline model would be to just predict a probability of 0.0 for every patient. That will result in 72.6% accuracy.
#
# Any fancy model we build needs to do better than this.
#
# We will come back to this later.

# %% [markdown]
# ## Preprocessing
#
# This dataset has both categorical variables and numeric variables.
#
# It will be convenient (for later processing) to collect these groups of variables into two lists.

# %%
categorical_variables = ['sex', 'cp', 'fbs', 'restecg','exang', 'ca', 'thal']
numerics = ['age', 'trestbps','chol', 'thalach', 'oldpeak', 'slope']

# %% [markdown]
# NNs require all their inputs to be numeric so we will first preprocess this raw data as follows:
# - *one-hot encode* the categorical variables
# - *normalize* the numeric variables
#
#
# With the pandas `get_dummies` function, you can one-hot-encode in one line.

# %%
df = pd.get_dummies(df, columns = categorical_variables)

# %%
df.head()
# Out:
#    age  trestbps  chol  thalach  oldpeak  slope  target  sex_0  sex_1   cp_0  \
# 0   63       145   233      150      2.3      3       0  False   True  False
# 1   67       160   286      108      1.5      2       1  False   True  False
# 2   67       120   229      129      2.6      2       0  False   True  False
# 3   37       130   250      187      3.5      3       0  False   True  False
# 4   41       130   204      172      1.4      1       0   True  False  False
#
#    ...  exang_1   ca_0   ca_1   ca_2   ca_3  thal_1  thal_2  thal_fixed  \
# 0  ...    False   True  False  False  False   False   False        True
# 1  ...     True  False  False  False   True   False   False       False
# 2  ...     True  False  False   True  False   False   False       False
# 3  ...    False   True  False  False  False   False   False       False
# 4  ...    False   True  False  False  False   False   False       False
#
#    thal_normal  thal_reversible
# 0        False            False
# 1         True            False
# 2        False             True
# 3         True            False
# 4         True            False
#
# [5 rows x 30 columns]

# %% [markdown]
# NNs work best when the inputs are all roughly in the same range. So standard practice is to **standardize** the numeric variables.
#
# Before we do so, let's split the data into an 80% training set and 20% test set (*why should we split **before** normalization?*).

# %%
test_df = df.sample(frac=0.2, random_state=42)
train_df = df.drop(test_df.index)

# %%
train_df.shape
# Out:
# (242, 30)

# %%
test_df.shape
# Out:
# (61, 30)

# %% [markdown]
# OK, let's calculate the mean and standard deviation of every numeric variable in the training set.

# %%
means = train_df[numerics].mean()
sd = train_df[numerics].std()

# %%
means
# Out:
# age          54.268595
# trestbps    131.995868
# chol        246.512397
# thalach     149.805785
# oldpeak       1.032645
# slope         1.590909
# dtype: float64

# %% [markdown]
# Let's standardize the train and test dataframes with these means and standard deviations.

# %%
train_df[numerics]= (train_df[numerics] - means)/sd

# %%
test_df[numerics]= (test_df[numerics] - means)/sd

# %%
train_df.head()
# Out:
#         age  trestbps      chol   thalach   oldpeak     slope  target  sex_0  \
# 0  0.963746  0.721939 -0.278690  0.008396  1.083461  2.226814       0  False
# 1  1.405254  1.554681  0.814423 -1.807247  0.399542  0.646494       1  False
# 2  1.405254 -0.665964 -0.361189 -0.899426  1.339930  0.646494       0  False
# 3 -1.906055 -0.110803  0.071931  1.607891  2.109339  2.226814       0  False
# 4 -1.464547 -0.110803 -0.876809  0.959447  0.314052 -0.933825       0   True
#
#    sex_1   cp_0  ...  exang_1   ca_0   ca_1   ca_2   ca_3  thal_1  thal_2  \
# 0   True  False  ...    False   True  False  False  False   False   False
# 1   True  False  ...     True  False  False  False   True   False   False
# 2   True  False  ...     True  False  False   True  False   False   False
# 3   True  False  ...    False   True  False  False  False   False   False
# 4  False  False  ...    False   True  False  False  False   False   False
#
#    thal_fixed  thal_normal  thal_reversible
# 0        True        False            False
# 1       False         True            False
# 2       False        False             True
# 3       False         True            False
# 4       False         True            False
#
# [5 rows x 30 columns]

# %% [markdown]
# At this point, the data is entirely numeric.
#
# The easiest way to feed data to Keras/Tensorflow is as Numpy arrays so we convert our two dataframes to Numpy arrays.

# %%
train = train_df.to_numpy()
test = test_df.to_numpy()

# %% [markdown]
# Final step: Our features $X$ and dependent variable $y$ are both inside the `train` and `test` arrays so let's separate them out.
#
# Note that the `target` column is our $y$ variable and it is column #6 from the left (counting from 0).
#
# The `np.delete` function is perfect for selecting all columns except one.

# %%
train_X = np.delete(train, 6, axis=1).astype('float32')
test_X = np.delete(test, 6, axis=1).astype('float32')

# %% [markdown]
# Check that it worked.

# %%
train_X.shape, test_X.shape
# Out:
# ((242, 29), (61, 29))

# %% [markdown]
# Next, select just the 6th column and define the train and test $y$ variables.

# %%
train_y = train[:, 6].astype('float32')
test_y = test[:, 6].astype('float32')

# %%
train_y.shape, test_y.shape
# Out:
# ((242,), (61,))

# %% [markdown]
# ## Build a model

# %% [markdown]
# ### Define model in Keras
#
# Creating an NN  is usually just a few lines of Keras code as we saw in class.
#
# * We will start with a single hidden layer.
# * Since this is a *binary classification problem*, we will use a sigmoid activation in the output layer.
#
# The following model is what we created in class.

# %%
num_columns = train_X.shape[1]

# define the input layer
input = keras.Input(shape=(num_columns,))

# feed the input vector to the hidden layer
# optional: you can give names to each layer to help
# keep track. This doesn't affect the training etc.

h = keras.layers.Dense(16, activation="relu", name="Hidden")(input)

# feed the output of the hidden layer to the output layer
output = keras.layers.Dense(1, activation="sigmoid", name="Output")(h)

# tell Keras that this (input,output) pair is your model
model = keras.Model(input, output)

# %% [markdown]
# The `model.summary()` command is a good way to get a quick overview of what you have defined.

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 29)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden (Dense)                  │ (None, 16)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 497 (1.94 KB)
#  Trainable params: 497 (1.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Let's hand-calculate the number of parameters to verify.

# %%
(29 + 1)* 16 + (16 + 1) * 1
# Out:
# 497

# %% [markdown]
# We can "visualize" the network graphically as well using Keras' `plot_model` function.

# %%
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ### Set optimization parameters

# %% [markdown]
# Now that the model is defined, we need to tell Keras three things:
#
# *   What **loss function** to use - Since our output variable is binary, we will select the `binary_crossentropy` loss function.
# *   Which **optimizer** to use - we will use a sibling of SGD called **Adam** which is an excellent default choice
# *   What **metrics** you want Keras to report out - in classification problems like this one, Accuracy is usually the metric you want to see.
#
# These three choices can be made using the `model.fit` function.

# %%
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ## Train the model
#
# To kickoff training, we have to decide on three things:
# * The *batch size*. We referred to this as a *minibatch* in lecture but in keeping with convention, we will simply refer to it as *batch* from this point on. 32 is a good default for the batch size.
# * The number of *epochs* i.e., how many passes through the training data. Usually 20-30 epochs is a good starting point but since this dataset is very small, each epoch will be very quick so let's run it for 300 epochs. It will allow us to see if any overfitting happens
# * Whether we want to use a validation set. This will be useful for overfitting detection and regularization via early stopping so we will ask Keras to automatically use 20% of the data points as a validation set

# %% [markdown]
# OK, let's train the model using the `model.fit` function!
#
# We will store the output of the training process in `history`. It will make it easy later to investigate what happened during training.

# %%
history = model.fit(train_X,              # the array with the input X columns
                    train_y,              # the array with the output y column
                    epochs=300,           # number of epochs to run
                    batch_size=32,        # number of samples (ie data points) per batch
                    verbose=1,            # verbosity during training
                    validation_split=0.2) # use 20% of the data for validation
# Out:
# Epoch 1/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5389 - loss: 0.6756 - val_accuracy: 0.5102 - val_loss: 0.6929
# Epoch 2/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6425 - loss: 0.6317 - val_accuracy: 0.5714 - val_loss: 0.6654
# Epoch 3/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7254 - loss: 0.5961 - val_accuracy: 0.6531 - val_loss: 0.6421
# Epoch 4/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7772 - loss: 0.5643 - val_accuracy: 0.6531 - val_loss: 0.6216
# Epoch 5/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7979 - loss: 0.5358 - val_accuracy: 0.6531 - val_loss: 0.6038
# Epoch 6/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8031 - loss: 0.5101 - val_accuracy: 0.6735 - val_loss: 0.5878
# Epoch 7/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8031 - loss: 0.4871 - val_accuracy: 0.6939 - val_loss: 0.5732
# Epoch 8/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8031 - loss: 0.4665 - val_accuracy: 0.7143 - val_loss: 0.5603
# Epoch 9/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8135 - loss: 0.4482 - val_accuracy: 0.7143 - val_loss: 0.5492
# Epoch 10/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8238 - loss: 0.4318 - val_accuracy: 0.7143 - val_loss: 0.5393
# Epoch 11/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8238 - loss: 0.4172 - val_accuracy: 0.7143 - val_loss: 0.5309
# Epoch 12/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8238 - loss: 0.4042 - val_accuracy: 0.6939 - val_loss: 0.5237
# Epoch 13/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8342 - loss: 0.3927 - val_accuracy: 0.6939 - val_loss: 0.5178
# Epoch 14/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.
300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9223 - loss: 0.1906 - val_accuracy: 0.7755 - val_loss: 0.4996
# Epoch 110/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9223 - loss: 0.1897 - val_accuracy: 0.7755 - val_loss: 0.5004
# Epoch 111/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9223 - loss: 0.1889 - val_accuracy: 0.7755 - val_loss: 0.5011
# Epoch 112/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9223 - loss: 0.1880 - val_accuracy: 0.7755 - val_loss: 0.5018
# Epoch 113/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9223 - loss: 0.1872 - val_accuracy: 0.7755 - val_loss: 0.5024
# Epoch 114/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9223 - loss: 0.1863 - val_accuracy: 0.7755 - val_loss: 0.5033
# Epoch 115/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9223 - loss: 0.1855 - val_accuracy: 0.7755 - val_loss: 0.5040
# Epoch 116/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9223 - loss: 0.1846 - val_accuracy: 0.7755 - val_loss: 0.5047
# Epoch 117/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9223 - loss: 0.1838 - val_accuracy: 0.7755 - val_loss: 0.5054
# Epoch 118/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9223 - loss: 0.1830 - val_accuracy: 0.7755 - val_loss: 0.5060
# Epoch 119/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9223 - loss: 0.1822 - val_accuracy: 0.7755 - val_loss: 0.5068
# Epoch 120/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9223 - loss: 0.1814 - val_accuracy: 0.7755 - val_loss: 0.5078
# Epoch 121/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9275 - loss: 0.1805 - val_accuracy: 0.7755 - val_loss: 0.5088
# Epoch 122/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9275 - loss: 0.1797 - val_accuracy: 0.7755 - val_loss: 0.5097
# Epoch 123/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1789 - val_accuracy: 0.7755 - val_loss: 0.5104
# Epoch 124/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1781 - val_accuracy: 0.7755 - val_loss: 0.5113
# Epoch 125/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9275 - loss: 0.1773 - val_accuracy: 0.7755 - val_loss: 0.5123
# Epoch 126/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9275 - loss: 0.1765 - val_accuracy: 0.7755 - val_loss: 0.5133
# Epoch 127/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9326 - loss: 0.1757 - val_accuracy: 0.7755 - val_loss: 0.5141
# Epoch 128/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9326 - loss: 0.1749 - val_accuracy: 0.7755 - val_loss: 0.5150
# Epoch 129/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9326 - loss: 0.1741 - val_accuracy: 0.7755 - val_loss: 0.5160
# Epoch 130/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9326 - loss: 0.1734 - val_accuracy: 0.7755 - val_loss: 0.5170
# Epoch 131/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9326 - loss: 0.1726 - val_accuracy: 0.7755 - val_loss: 0.5181
# Epoch 132/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9326 - loss: 0.1718 - val_accuracy: 0.7755 - val_loss: 0.5190
# Epoch 133/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9275 - loss: 0.1710 - val_accuracy: 0.7755 - val_loss: 0.5199
# Epoch 134/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9275 - loss: 0.1702 - val_accuracy: 0.7755 - val_loss: 0.5212
# Epoch 135/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9275 - loss: 0.1695 - val_accuracy: 0.7755 - val_loss: 0.5223
# Epoch 136/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1687 - val_accuracy: 0.7755 - val_loss: 0.5233
# Epoch 137/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1679 - val_accuracy: 0.7755 - val_loss: 0.5247
# Epoch 138/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9275 - loss: 0.1671 - val_accuracy: 0.7755 - val_loss: 0.5255
# Epoch 139/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9275 - loss: 0.1664 - val_accuracy: 0.7755 - val_loss: 0.5266
# Epoch 140/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9275 - loss: 0.1656 - val_accuracy: 0.7755 - val_loss: 0.5281
# Epoch 141/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9275 - loss: 0.1649 - val_accuracy: 0.7755 - val_loss: 0.5292
# Epoch 142/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1641 - val_accuracy: 0.7755 - val_loss: 0.5302
# Epoch 143/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9275 - loss: 0.1633 - val_accuracy: 0.7755 - val_loss: 0.5315
# Epoch 144/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1625 - val_accuracy: 0.7755 - val_loss: 0.5325
# Epoch 145/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1617 - val_accuracy: 0.7755 - val_loss: 0.5334
# Epoch 146/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1609 - val_accuracy: 0.7755 - val_loss: 0.5345
# Epoch 147/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9275 - loss: 0.1602 - val_accuracy: 0.7755 - val_loss: 0.5358
# Epoch 148/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9275 - loss: 0.1594 - val_accuracy: 0.7755 - val_loss: 0.5367
# Epoch 149/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9326 - loss: 0.1586 - val_accuracy: 0.7755 - val_loss: 0.5379
# Epoch 150/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9326 - loss: 0.1579 - val_accuracy: 0.7755 - val_loss: 0.5391
# Epoch 151/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9326 - loss: 0.1571 - val_accuracy: 0.7755 - val_loss: 0.5403
# Epoch 152/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9326 - loss: 0.1563 - val_accuracy: 0.7755 - val_loss: 0.5414
# Epoch 153/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9378 - loss: 0.1555 - val_accuracy: 0.7755 - val_loss: 0.5423
# Epoch 154/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9378 - loss: 0.1548 - val_accuracy: 0.7755 - val_loss: 0.5434
# Epoch 155/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9378 - loss: 0.1540 - val_accuracy: 0.7755 - val_loss: 0.5448
# Epoch 156/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9378 - loss: 0.1532 - val_accuracy: 0.7755 - val_loss: 0.5457
# Epoch 157/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9378 - loss: 0.1524 - val_accuracy: 0.7755 - val_loss: 0.5469
# Epoch 158/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9378 - loss: 0.1516 - val_accuracy: 0.7755 - val_loss: 0.5482
# Epoch 159/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9378 - loss: 0.1509 - val_accuracy: 0.7755 - val_loss: 0.5490
# Epoch 160/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9378 - loss: 0.1501 - val_accuracy: 0.7755 - val_loss: 0.5499
# Epoch 161/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9378 - loss: 0.1492 - val_accuracy: 0.7755 - val_loss: 0.5512
# Epoch 162/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9378 - loss: 0.1484 - val_accuracy: 0.7755 - val_loss: 0.5528
# Epoch 163/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9378 - loss: 0.1477 - val_accuracy: 0.7755 - val_loss: 0.5538
# Epoch 164/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9378 - loss: 0.1468 - val_accuracy: 0.7755 - val_loss: 0.5550
# Epoch 165/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9378 - loss: 0.1460 - val_accuracy: 0.7755 - val_loss: 0.5562
# Epoch 166/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9378 - loss: 0.1452 - val_accuracy: 0.7755 - val_loss: 0.5572
# Epoch 167/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9378 - loss: 0.1444 - val_accuracy: 0.7755 - val_loss: 0.5587
# Epoch 168/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9482 - loss: 0.1436 - val_accuracy: 0.7755 - val_loss: 0.5601
# Epoch 169/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9482 - loss: 0.1428 - val_accuracy: 0.7755 - val_loss: 0.5610
# Epoch 170/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9482 - loss: 0.1421 - val_accuracy: 0.7755 - val_loss: 0.5623
# Epoch 171/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9482 - loss: 0.1413 - val_accuracy: 0.7755 - val_loss: 0.5635
# Epoch 172/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9482 - loss: 0.1405 - val_accuracy: 0.7755 - val_loss: 0.5644
# Epoch 173/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9482 - loss: 0.1398 - val_accuracy: 0.7755 - val_loss: 0.5658
# Epoch 174/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9482 - loss: 0.1391 - val_accuracy: 0.7755 - val_loss: 0.5669
# Epoch 175/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9482 - loss: 0.1383 - val_accuracy: 0.7755 - val_loss: 0.5677
# Epoch 176/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9482 - loss: 0.1375 - val_accuracy: 0.7755 - val_loss: 0.5685
# Epoch 177/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9482 - loss: 0.1367 - val_accuracy: 0.7755 - val_loss: 0.5697
# Epoch 178/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9482 - loss: 0.1360 - val_accuracy: 0.7755 - val_loss: 0.5704
# Epoch 179/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9482 - loss: 0.1352 - val_accuracy: 0.7755 - val_loss: 0.5713
# Epoch 180/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9482 - loss: 0.1344 - val_accuracy: 0.7755 - val_loss: 0.5722
# Epoch 181/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9482 - loss: 0.1336 - val_accuracy: 0.7755 - val_loss: 0.5734
# Epoch 182/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9534 - loss: 0.1329 - val_accuracy: 0.7755 - val_loss: 0.5744
# Epoch 183/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1321 - val_accuracy: 0.7755 - val_loss: 0.5752
# Epoch 184/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9534 - loss: 0.1313 - val_accuracy: 0.7755 - val_loss: 0.5756
# Epoch 185/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1306 - val_accuracy: 0.7755 - val_loss: 0.5768
# Epoch 186/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1298 - val_accuracy: 0.7755 - val_loss: 0.5777
# Epoch 187/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9534 - loss: 0.1290 - val_accuracy: 0.7755 - val_loss: 0.5783
# Epoch 188/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1282 - val_accuracy: 0.7959 - val_loss: 0.5793
# Epoch 189/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9534 - loss: 0.1275 - val_accuracy: 0.7959 - val_loss: 0.5800
# Epoch 190/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1267 - val_accuracy: 0.7959 - val_loss: 0.5807
# Epoch 191/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1260 - val_accuracy: 0.7959 - val_loss: 0.5818
# Epoch 192/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1252 - val_accuracy: 0.7959 - val_loss: 0.5827
# Epoch 193/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1244 - val_accuracy: 0.7959 - val_loss: 0.5837
# Epoch 194/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9534 - loss: 0.1237 - val_accuracy: 0.7959 - val_loss: 0.5847
# Epoch 195/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1230 - val_accuracy: 0.7959 - val_loss: 0.5856
# Epoch 196/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1222 - val_accuracy: 0.7959 - val_loss: 0.5865
# Epoch 197/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9534 - loss: 0.1214 - val_accuracy: 0.7959 - val_loss: 0.5875
# Epoch 198/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1207 - val_accuracy: 0.7959 - val_loss: 0.5883
# Epoch 199/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9534 - loss: 0.1199 - val_accuracy: 0.7959 - val_loss: 0.5894
# Epoch 200/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1191 - val_accuracy: 0.7959 - val_loss: 0.5905
# Epoch 201/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1184 - val_accuracy: 0.7959 - val_loss: 0.5913
# Epoch 202/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.1177 - val_accuracy: 0.7959 - val_loss: 0.5922
# Epoch 203/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9534 - loss: 0.1169 - val_accuracy: 0.7959 - val_loss: 0.5934
# Epoch 204/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9585 - loss: 0.1161 - val_accuracy: 0.7959 - val_loss: 0.5945
# Epoch 205/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9585 - loss: 0.1154 - val_accuracy: 0.7959 - val_loss: 0.5954
# Epoch 206/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9585 - loss: 0.1146 - val_accuracy: 0.7959 - val_loss: 0.5961
# Epoch 207/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9585 - loss: 0.1139 - val_accuracy: 0.7959 - val_loss: 0.5973
# Epoch 208/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9585 - loss: 0.1131 - val_accuracy: 0.7959 - val_loss: 0.5982
# Epoch 209/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9585 - loss: 0.1124 - val_accuracy: 0.7959 - val_loss: 0.5989
# Epoch 210/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.
300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9948 - loss: 0.0757 - val_accuracy: 0.7755 - val_loss: 0.6824
# Epoch 275/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9948 - loss: 0.0753 - val_accuracy: 0.7755 - val_loss: 0.6834
# Epoch 276/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9948 - loss: 0.0748 - val_accuracy: 0.7755 - val_loss: 0.6851
# Epoch 277/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9948 - loss: 0.0744 - val_accuracy: 0.7755 - val_loss: 0.6868
# Epoch 278/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9948 - loss: 0.0739 - val_accuracy: 0.7755 - val_loss: 0.6879
# Epoch 279/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0735 - val_accuracy: 0.7755 - val_loss: 0.6892
# Epoch 280/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9948 - loss: 0.0730 - val_accuracy: 0.7755 - val_loss: 0.6908
# Epoch 281/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0727 - val_accuracy: 0.7755 - val_loss: 0.6920
# Epoch 282/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0721 - val_accuracy: 0.7755 - val_loss: 0.6932
# Epoch 283/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0717 - val_accuracy: 0.7755 - val_loss: 0.6947
# Epoch 284/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0713 - val_accuracy: 0.7755 - val_loss: 0.6965
# Epoch 285/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0709 - val_accuracy: 0.7755 - val_loss: 0.6976
# Epoch 286/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9948 - loss: 0.0704 - val_accuracy: 0.7755 - val_loss: 0.6988
# Epoch 287/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9948 - loss: 0.0700 - val_accuracy: 0.7755 - val_loss: 0.7002
# Epoch 288/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0696 - val_accuracy: 0.7755 - val_loss: 0.7015
# Epoch 289/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0691 - val_accuracy: 0.7755 - val_loss: 0.7027
# Epoch 290/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9948 - loss: 0.0688 - val_accuracy: 0.7755 - val_loss: 0.7041
# Epoch 291/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0683 - val_accuracy: 0.7755 - val_loss: 0.7053
# Epoch 292/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9948 - loss: 0.0679 - val_accuracy: 0.7755 - val_loss: 0.7069
# Epoch 293/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9948 - loss: 0.0675 - val_accuracy: 0.7755 - val_loss: 0.7086
# Epoch 294/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9948 - loss: 0.0671 - val_accuracy: 0.7755 - val_loss: 0.7094
# Epoch 295/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9948 - loss: 0.0666 - val_accuracy: 0.7755 - val_loss: 0.7109
# Epoch 296/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0663 - val_accuracy: 0.7755 - val_loss: 0.7124
# Epoch 297/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0659 - val_accuracy: 0.7755 - val_loss: 0.7136
# Epoch 298/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9948 - loss: 0.0654 - val_accuracy: 0.7755 - val_loss: 0.7144
# Epoch 299/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9948 - loss: 0.0651 - val_accuracy: 0.7755 - val_loss: 0.7157
# Epoch 300/300
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9948 - loss: 0.0647 - val_accuracy: 0.7755 - val_loss: 0.7169

# %% [markdown]
# Let's take a moment to understand the numbers being reported.
#
#
# ---

# %% [markdown]
# Plotting metrics like loss and accuracy as a function of the # of epochs is a good way to understand how training has progressed.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# Do you think there's overfitting?
#
# <br> <br> <br> <br> <br> <br> <br> <br>
#
#
#
# There does seem to be overfitting.
#
# If there's overfitting at epoch N, we could go back, re-initialize the model and just run it for  N epochs - that would an example of **early stopping**.
#
#
# Let's look at the accuracy curves as well.

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluate the model
#
# Let's see **how well the model does on the test set**.
#
# `model.evaluate` is a very handy function to calculate the performance of your model on any dataset.

# %%
model.evaluate(test_X, test_y)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8197 - loss: 0.5380
# [0.5380478501319885, 0.8196721076965332]
